# %%
import os
import json
import jsonlines
import pandas as pd

# %%
os.chdir(os.path.join(os.getcwd(), 'data'))

df = pd.read_excel('markers.xlsx')
df_board = pd.read_excel('board.xlsx')
df.shape
# Out:
# (109, 14)

# %% [markdown]
# ## 原始数据

# %%
df.head()
# Out:
#   type   name short_name  desc logo  images phone address   panorama  \
# 0   景点  孙中山铜像         铜像  地点描述  NaN     2.0   NaN      地址  2291779.0
# 1   景点    校训石        NaN  地点描述  NaN     1.0   NaN     NaN        NaN
# 2   景点    南芳湖        NaN  地点描述  NaN     2.0   NaN     NaN        NaN
# 3   景点   西区公园        NaN  地点描述  NaN     2.0   NaN     NaN        NaN
# 4   景点    大礼堂        NaN  地点描述  NaN     3.0   NaN     NaN        NaN
#
#                location  icon  position  scale                       _id
# 0  23.634548,113.676900  tx@2       0.0   16.0  5ce8fe1c29c7a8581bc1e98b
# 1  23.634037,113.677393   NaN       NaN    NaN                       NaN
# 2  23.629113,113.679507   NaN       NaN    NaN                       NaN
# 3  23.629958,113.677726   NaN       NaN    NaN                       NaN
# 4  23.631772,113.679662   NaN       NaN    NaN                       NaN

# %%
df[['images', 'panorama', 'position']] = df[['images', 'panorama', 'position']].fillna(0).astype('int')
df.head()
# Out:
#   type   name short_name  desc logo  images phone address  panorama  \
# 0   景点  孙中山铜像         铜像  地点描述  NaN       2   NaN      地址   2291779
# 1   景点    校训石        NaN  地点描述  NaN       1   NaN     NaN         0
# 2   景点    南芳湖        NaN  地点描述  NaN       2   NaN     NaN         0
# 3   景点   西区公园        NaN  地点描述  NaN       2   NaN     NaN         0
# 4   景点    大礼堂        NaN  地点描述  NaN       3   NaN     NaN         0
#
#                location  icon  position  scale                       _id
# 0  23.634548,113.676900  tx@2         0   16.0  5ce8fe1c29c7a8581bc1e98b
# 1  23.634037,113.677393   NaN         0    NaN                       NaN
# 2  23.629113,113.679507   NaN         0    NaN                       NaN
# 3  23.629958,113.677726   NaN         0    NaN                       NaN
# 4  23.631772,113.679662   NaN         0    NaN                       NaN

# %% [markdown]
# ## 目标数据格式
# ```
# {
#     type: '景点',
#     scale: 15.0,
#     icon: 'jt',
#     postion: 0,
#     data:   [
#         {
#             name: "孙中山铜像",
#             short_name: "铜像",
#             desc: "中山铜像...",
#             logo: "tx",
#             icon: "tx@2",
#             images: 3,
#             panorama: 0,
#             latitude: "23.635875",
#             longitude: "113.678965",
#             contact: { phone: "020-123456", address: "出门左转" }
#          },
#              ...
#          {...}
#       ]
# }
# ```

# %%
# 填充NaN值
df.fillna('', inplace=True)

# %%
# location
df['latitude'] = df.apply(lambda x:x.location.split(',')[0], axis=1)
df['longitude'] =df.apply(lambda x:x.location.split(',')[1], axis=1)
df.drop('location', axis=1, inplace=True)
df.tail()
# Out:
#     type      name short_name  \
# 104   校区  中山大学南方学院         南苑
# 105   探险      校长别墅
# 106   探险        后山
# 107   探险     大礼堂之巅       天台风凉
# 108   探险       枫林晚
#
#                                                   desc    logo  images  \
# 104  中山大学南方学院是2006年经教育部批准，由中山大学与广东珠江投资集团合作创办的独立学院，是...  nfsysu       2
# 105                                               地点描述               1
# 106                                               地点描述               1
# 107                                               地点描述               1
# 108                                            锦衣夜游好去处               1
#
#             phone                 address  panorama   icon  position scale  \
# 104  020-61787201  广州市从化区温泉大道882号中山大学南方学院   2291778               11
# 105                                               0               10
# 106                                               0  climb         0
# 107                                               0                0
# 108                                               0                0
#
#                                                   _id   latitude   longitude
# 104  Rok4jKCtqaeJQmkYMlvk1G30I46gM0TEpKX9c8DziJZzWewg  23.632674  113.679404
# 105  wkNEmpv7L4Th8yfd1Dl34gDzSLlnmLFGF16ACmQ7fIZAMzzV  23.635659  113.678386
# 106                                                    23.632258  113.673241
# 107                                                    23.631629  113.679914
# 108                                                    23.636455  113.680172

# %%
# contact
df['contact'] = df.apply(lambda x:{
    'phone': x.phone,
    'address': x.address
}, axis=1)
df.drop(['phone', 'address'], axis=1, inplace=True)
df.tail()
# Out:
#     type      name short_name  \
# 104   校区  中山大学南方学院         南苑
# 105   探险      校长别墅
# 106   探险        后山
# 107   探险     大礼堂之巅       天台风凉
# 108   探险       枫林晚
#
#                                                   desc    logo  images  \
# 104  中山大学南方学院是2006年经教育部批准，由中山大学与广东珠江投资集团合作创办的独立学院，是...  nfsysu       2
# 105                                               地点描述               1
# 106                                               地点描述               1
# 107                                               地点描述               1
# 108                                            锦衣夜游好去处               1
#
#      panorama   icon  position scale  \
# 104   2291778               11
# 105         0               10
# 106         0  climb         0
# 107         0                0
# 108         0                0
#
#                                                   _id   latitude   longitude  \
# 104  Rok4jKCtqaeJQmkYMlvk1G30I46gM0TEpKX9c8DziJZzWewg  23.632674  113.679404
# 105  wkNEmpv7L4Th8yfd1Dl34gDzSLlnmLFGF16ACmQ7fIZAMzzV  23.635659  113.678386
# 106                                                    23.632258  113.673241
# 107                                                    23.631629  113.679914
# 108                                                    23.636455  113.680172
#
#                                                contact
# 104  {'phone': '020-61787201', 'address': '广州市从化区温泉...
# 105                       {'phone': '', 'address': ''}
# 106                       {'phone': '', 'address': ''}
# 107                       {'phone': '', 'address': ''}
# 108                       {'phone': '', 'address': ''}

# %%
import pinyin

def get_pinyin_first_alpha(name):
    '''
        根据type中文名转为拼音缩写，用以匹配icon
    '''
    return "".join([i[0] for i in pinyin.get(name, " ").split(" ")])

# %%
data = [{'type': t, 'icon': get_pinyin_first_alpha(t), 'data': []} for t in set(df.type)] 
data
# Out:
# [{'type': '交通', 'icon': 'jt', 'data': []},
#  {'type': '食堂', 'icon': 'st', 'data': []},
#  {'type': '体育场所', 'icon': 'tycs', 'data': []},
#  {'type': '校区', 'icon': 'xq', 'data': []},
#  {'type': '学生宿舍', 'icon': 'xsss', 'data': []},
#  {'type': '生活服务', 'icon': 'shfw', 'data': []},
#  {'type': '行政楼', 'icon': 'xzl', 'data': []},
#  {'type': '校门', 'icon': 'xm', 'data': []},
#  {'type': '教学楼', 'icon': 'jxl', 'data': []},
#  {'type': '教工宿舍', 'icon': 'jgss', 'data': []},
#  {'type': '景点', 'icon': 'jd', 'data': []},
#  {'type': '探险', 'icon': 'tx', 'data': []}]

# %%
for index, row in df.iterrows():
    for i in data:
        if i['type'] == row.type:
            i['data'].append(dict(row))
            if row.scale != '':
                i['scale'] = i['data'][0]['scale']
            if row.position != '':
                i['position'] = i['data'][0]['position']
            if row._id != '':
                i['_id'] = i['data'][0]['_id']
data
# Out:
# [{'type': '交通',
#   'icon': 'jt',
#   'data': [{'type': '交通',
#     'name': '卫东(公交站)',
#     'short_name': '卫东站',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 0,
#     'panorama': 0,
#     'icon': 'station',
#     'position': 3,
#     'scale': 15.0,
#     '_id': '5ce8fe1c29c7a8581bc1e991',
#     'latitude': '23.644299',
#     'longitude': '113.671715',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '交通',
#     'name': '校车站',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 2,
#     'panorama': 0,
#     'icon': 'station',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6352853977',
#     'longitude': '113.6773502827',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '交通',
#     'name': '停车场（铜像）',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.634622',
#     'longitude': '113.676449',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '交通',
#     'name': '停车场（行政楼）',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 0,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.633103',
#     'longitude': '113.676417',
#     'contact': {'phone': '', 'address': ''}}],
#   'scale': 15.0,
#   'position': 3,
#   '_id': '5ce8fe1c29c7a8581bc1e991'},
#  {'type': '食堂',
#   'icon': 'st',
#   'data': [{'type': '食堂',
#     'name': '西区食堂',
#     'short_name': '西饭',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 2,
#     'panorama': 0,
#     'icon': '',
#     'position': 5,
#     'scale': 17.0,
#     '_id': '5ce8fe1c29c7a8581bc1e995',
#     'latitude': '23.6317961065',
#     'longitude': '113.6758750677',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '食堂',
#     'name': '中区食堂',
#     'short_name': '中饭',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 9,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6348086972',
#     'longitude': '113.6793458462',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '食堂',
#     'name': '东区食堂',
#     'short_name': '东饭',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.634174732',
#     'longitude': '113.6822855473',
#     'contact': {'phone': '', 'address': ''}}],
#   'scale': 17.0,
#   'position': 5,
#   '_id': '5ce8fe1c29c7a8581bc1e995'},
#  {'type': '体育场所',
#   'icon': 'tycs',
#   'data': [{'type': '体育场所',
#     'name': '东区操场',
#     'short_name': '东操',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 4,
#     'panorama': 0,
#     'icon': '',
#     'position': 8,
#     'scale': 16.0,
#     '_id': '5ce8fe1c29c7a8581bc1e98f',
#     'latitude': '23.6322482452',
#     'longitude': '113.6813092232',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '体育场所',
#     'name': '西区操场',
#     'short_name': '西操',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6321499543',
#     'longitude': '113.6749362946',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '体育场所',
#     'name': '东区篮球场',
#     'short_name': '东篮',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 2,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6323170488',
#     'longitude': '113.6819422245',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '体育场所',
#     'name': '西区篮球场',
#     'short_name': '西篮',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6335555072',
#     'longitude': '113.6757731438',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '体育场所',
#     'name': '南区篮球场',
#     'short_name': '南篮',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6294862428',
#     'longitude': '113.6778652668',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '体育场所',
#     'name': '东区体育馆',
#     'short_name': '东体',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6333196113',
#     'longitude': '113.6813521385',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '体育场所',
#     'name': '西区体育馆',
#     'short_name': '西体',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.633103373',
#     'longitude': '113.6756336689',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '体育场所',
#     'name': '网球场',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6325627756',
#     'longitude': '113.676019907',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '体育场所',
#     'name': '排球场',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6341993043',
#     'longitude': '113.6761271954',
#     'contact': {'phone': '', 'address': ''}}],
#   'scale': 16.0,
#   'position': 8,
#   '_id': '5ce8fe1c29c7a8581bc1e98f'},
#  {'type': '校区',
#   'icon': 'xq',
#   'data': [{'type': '校区',
#     'name': '中山大学南方学院',
#     'short_name': '南苑',
#     'desc': '中山大学南方学院是2006年经教育部批准，由中山大学与广东珠江投资集团合作创办的独立学院，是一所多学科全日制应用型本科高等学校，2016年被遴选为广东省普通本科转型试点高校。',
#     'logo': 'nfsysu',
#     'images': 2,
#     'panorama': 2291778,
#     'icon': '',
#     'position': 11,
#     'scale': '',
#     '_id': 'Rok4jKCtqaeJQmkYMlvk1G30I46gM0TEpKX9c8DziJZzWewg',
#     'latitude': '23.632674',
#     'longitude': '113.679404',
#     'contact': {'phone': '020-61787201',
#      'address': '广州市从化区温泉大道882号中山大学南方学院'}}],
#   'position': 11,
#   '_id': 'Rok4jKCtqaeJQmkYMlvk1G30I46gM0TEpKX9c8DziJZzWewg'},
#  {'type': '学生宿舍',
#   'icon': 'xsss',
#   'data': [{'type': '学生宿舍',
#     'name': '西学楼1号',
#     'short_name': '西1',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 6,
#     'scale': 16.0,
#     '_id': '5ce8fe1c29c7a8581bc1e998',
#     'latitude': '23.6305478022',
#     'longitude': '113.675558567',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '西学楼2号',
#     'short_name': '西2',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6299973651',
#     'longitude': '113.6758589745',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '西学楼3号',
#     'short_name': '西3',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6296779139',
#     'longitude': '113.6759662628',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '西学楼4号',
#     'short_name': '西4',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6293388033',
#     'longitude': '113.6761915684',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '西学楼5号',
#     'short_name': '西5',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6290340945',
#     'longitude': '113.6763042212',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '西学楼6号',
#     'short_name': '西6',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6308475929',
#     'longitude': '113.6763525009',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '西学楼7号',
#     'short_name': '西7',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6304052786',
#     'longitude': '113.6765617132',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '西学楼8号',
#     'short_name': '西8',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6299383896',
#     'longitude': '113.6767655611',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '西学楼9号',
#     'short_name': '西9',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6294714989',
#     'longitude': '113.6770015955',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '西学楼10号',
#     'short_name': '西10',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6290684972',
#     'longitude': '113.6771517992',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '西学楼11号',
#     'short_name': '西11',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6285966887',
#     'longitude': '113.6773985624',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼12号',
#     'short_name': '东12',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6353394564',
#     'longitude': '113.6799252033',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼13号',
#     'short_name': '东13',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6350937348',
#     'longitude': '113.6805206537',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼14号',
#     'short_name': '东14',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6347693816',
#     'longitude': '113.6808907986',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼15号',
#     'short_name': '东15',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6359046143',
#     'longitude': '113.6806118488',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼16号',
#     'short_name': '东16',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6356785514',
#     'longitude': '113.6811697483',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼17号',
#     'short_name': '东17',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6353541997',
#     'longitude': '113.6814916134',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼18号',
#     'short_name': '东18',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6349954461',
#     'longitude': '113.6818510294',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼19号',
#     'short_name': '东19',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6334670463',
#     'longitude': '113.6826074123',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼20号',
#     'short_name': '东20',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6331820051',
#     'longitude': '113.6826771498',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼21号',
#     'short_name': '东21',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6328478181',
#     'longitude': '113.682757616',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼22号',
#     'short_name': '东22',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6325627756',
#     'longitude': '113.68285954',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼23号',
#     'short_name': '东23',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6322040143',
#     'longitude': '113.6830472946',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼24号',
#     'short_name': '东24',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.632336707',
#     'longitude': '113.6838841438',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼25号',
#     'short_name': '东25',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6318747394',
#     'longitude': '113.683385253',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼26号',
#     'short_name': '东26',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6366172012',
#     'longitude': '113.6815452576',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼27号',
#     'short_name': '东27',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6362437079',
#     'longitude': '113.6819583178',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼28号',
#     'short_name': '东28',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6358947855',
#     'longitude': '113.6822801828',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼29号',
#     'short_name': '东29',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6347448094',
#     'longitude': '113.6828756332',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼30号',
#     'short_name': '东30',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6344007975',
#     'longitude': '113.6830687523',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼31号',
#     'short_name': '东31',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6341354162',
#     'longitude': '113.6832511425',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼32号',
#     'short_name': '东32',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6338159751',
#     'longitude': '113.6834710836',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼33号',
#     'short_name': '东33',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6334965333',
#     'longitude': '113.6837661266',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼34号',
#     'short_name': '东34',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6331721761',
#     'longitude': '113.6840558052',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '学生宿舍',
#     'name': '东学楼35号',
#     'short_name': '东35',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6328527327',
#     'longitude': '113.6845010519',
#     'contact': {'phone': '', 'address': ''}}],
#   'scale': 16.0,
#   'position': 6,
#   '_id': '5ce8fe1c29c7a8581bc1e998'},
#  {'type': '生活服务',
#   'icon': 'shfw',
#   'data': [{'type': '生活服务',
#     'name': '浦发银行（中）',
#     'short_name': '浦发银行',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 2,
#     'scale': 15.0,
#     '_id': '5ce8fe1c29c7a8581bc1e989',
#     'latitude': '23.635875',
#     'longitude': '113.678965',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '生活服务',
#     'name': '工商银行（东）',
#     'short_name': '工行',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 0,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.633836',
#     'longitude': '113.681889',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '生活服务',
#     'name': '工商银行（西）',
#     'short_name': '工行',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 0,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6317961065',
#     'longitude': '113.6758750677',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '生活服务',
#     'name': '招商银行（中）',
#     'short_name': '招行（中）',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.635792',
#     'longitude': '113.678960',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '生活服务',
#     'name': '招商银行（西）',
#     'short_name': '招行（西）',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.632145',
#     'longitude': '113.676063',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '生活服务',
#     'name': '菜鸟驿站',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.631708',
#     'longitude': '113.680392',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '生活服务',
#     'name': '网络服务中心',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.631201',
#     'longitude': '113.679609',
#     'contact': {'phone': '020-22099962', 'address': ''}},
#    {'type': '生活服务',
#     'name': '超市（东）',
#     'short_name': '东超',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 2,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.633767',
#     'longitude': '113.682350',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '生活服务',
#     'name': '超市（中）',
#     'short_name': '中超',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.634642',
#     'longitude': '113.679544',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '生活服务',
#     'name': '医务室',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 2,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.635969',
#     'longitude': '113.679405',
#     'contact': {'phone': '020-71787800', 'address': ''}},
#    {'type': '生活服务',
#     'name': '西区商业街',
#     'short_name': '商业街',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6312899058',
#     'longitude': '113.6764115095',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '生活服务',
#     'name': '后门集市',
#     'short_name': '集市',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 0,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.62752',
#     'longitude': '113.679796',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '生活服务',
#     'name': '招待所',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6309360556',
#     'longitude': '113.6753493547',
#     'contact': {'phone': '020-61787898', 'address': ''}}],
#   'scale': 15.0,
#   'position': 2,
#   '_id': '5ce8fe1c29c7a8581bc1e989'},
#  {'type': '行政楼',
#   'icon': 'xzl',
#   'data': [{'type': '行政楼',
#     'name': 'A1行政楼',
#     'short_name': 'A1',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 4,
#     'scale': 17.0,
#     '_id': '5ce8fe1c29c7a8581bc1e99a',
#     'latitude': '23.633693',
#     'longitude': '113.676830',
#     'contact': {'phone': '020-61787368', 'address': '学院办公室 A1-304'}},
#    {'type': '行政楼',
#     'name': 'A2行政楼',
#     'short_name': 'A2',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.634524',
#     'longitude': '113.677779',
#     'contact': {'phone': '020-61787191', 'address': ''}}],
#   'scale': 17.0,
#   'position': 4,
#   '_id': '5ce8fe1c29c7a8581bc1e99a'},
#  {'type': '校门',
#   'icon': 'xm',
#   'data': [{'type': '校门',
#     'name': '北门',
#     'short_name': '牌坊',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 2,
#     'panorama': 0,
#     'icon': '',
#     'position': 9,
#     'scale': 15.0,
#     '_id': '5ce8fe1c29c7a8581bc1e98d',
#     'latitude': '23.6437625136',
#     'longitude': '113.6716961861',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '校门',
#     'name': '南门',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 0,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6283656986',
#     'longitude': '113.6783373356',
#     'contact': {'phone': '', 'address': ''}}],
#   'scale': 15.0,
#   'position': 9,
#   '_id': '5ce8fe1c29c7a8581bc1e98d'},
#  {'type': '教学楼',
#   'icon': 'jxl',
#   'data': [{'type': '教学楼',
#     'name': '文学与传媒学院',
#     'short_name': '1教',
#     'desc': '地点描述',
#     'logo': '1j',
#     'images': 5,
#     'panorama': 0,
#     'icon': '',
#     'position': 1,
#     'scale': '',
#     '_id': '5ce8fe1c29c7a8581bc1e993',
#     'latitude': '23.631693',
#     'longitude': '113.676696',
#     'contact': {'phone': '020-6187352', 'address': '102办公室'}},
#    {'type': '教学楼',
#     'name': '电气与计算机工程学院',
#     'short_name': '2教',
#     'desc': '地点描述',
#     'logo': '2j',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.63127',
#     'longitude': '113.676846',
#     'contact': {'phone': '020-61787104', 'address': '104A办公室'}},
#    {'type': '教学楼',
#     'name': '外国语学院',
#     'short_name': '3教',
#     'desc': '地点描述',
#     'logo': '3j',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.630877',
#     'longitude': '113.677082',
#     'contact': {'phone': '020-61787318', 'address': '101办公室'}},
#    {'type': '教学楼',
#     'name': '艺术设计与创意产业系',
#     'short_name': '4教',
#     'desc': '地点描述',
#     'logo': '4j',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.630504',
#     'longitude': '113.677291',
#     'contact': {'phone': '020-61787318', 'address': '103办公室'}},
#    {'type': '教学楼',
#     'name': '会计学院',
#     'short_name': '5教',
#     'desc': '地点描述',
#     'logo': '5j',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.633924',
#     'longitude': '113.678021',
#     'contact': {'phone': '020-61787330', 'address': '101办公室'}},
#    {'type': '教学楼',
#     'name': '公共管理学系',
#     'short_name': '6教',
#     'desc': '地点描述',
#     'logo': '6j',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.633639',
#     'longitude': '113.678348',
#     'contact': {'phone': '020-61787344', 'address': '103办公室'}},
#    {'type': '教学楼',
#     'name': '医学与健康管理系',
#     'short_name': '7教',
#     'desc': '地点描述',
#     'logo': '7j',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.633344',
#     'longitude': '113.678611',
#     'contact': {'phone': '020-61787206', 'address': ''}},
#    {'type': '教学楼',
#     'name': '商学院',
#     'short_name': '8教',
#     'desc': '地点描述',
#     'logo': '8j',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6343762251',
#     'longitude': '113.680011034',
#     'contact': {'phone': '020-61787329', 'address': '106办公室'}},
#    {'type': '教学楼',
#     'name': '政商研究院',
#     'short_name': '9教',
#     'desc': '地点描述',
#     'logo': '9j',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6339634096',
#     'longitude': '113.6800646782',
#     'contact': {'phone': '020-61787455', 'address': ''}},
#    {'type': '教学楼',
#     'name': '国际学院',
#     'short_name': '10教',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6334768753',
#     'longitude': '113.6801236868',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教学楼',
#     'name': '教学楼11号',
#     'short_name': '11教',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6331574326',
#     'longitude': '113.680112958',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教学楼',
#     'name': '实验楼1号',
#     'short_name': '1实',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6314078556',
#     'longitude': '113.6782354116',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教学楼',
#     'name': '实验楼2号',
#     'short_name': '2实',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6309802869',
#     'longitude': '113.6784821749',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教学楼',
#     'name': '实验楼3号',
#     'short_name': '3实',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6305969483',
#     'longitude': '113.6786967516',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教学楼',
#     'name': '实验楼4号',
#     'short_name': '4实',
#     'desc': '地点描述',
#     'logo': '4s',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6327003824',
#     'longitude': '113.6800056696',
#     'contact': {'phone': '020-85220130', 'address': ''}},
#    {'type': '教学楼',
#     'name': '音乐系',
#     'short_name': '音乐楼',
#     'desc': '地点描述',
#     'logo': 'yyl',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6353394564',
#     'longitude': '113.6787986755',
#     'contact': {'phone': '020-39322771', 'address': ''}}],
#   'position': 1,
#   '_id': '5ce8fe1c29c7a8581bc1e993'},
#  {'type': '教工宿舍',
#   'icon': 'jgss',
#   'data': [{'type': '教工宿舍',
#     'name': '聚贤楼1号',
#     'short_name': '聚1',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 7,
#     'scale': '',
#     '_id': 'mrWfizMUpejXLXb2mSeShAtiLnoVuxDa17VRpVXKfsQiXNZM',
#     'latitude': '23.6301792062',
#     'longitude': '113.6783856153',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教工宿舍',
#     'name': '聚贤楼2号',
#     'short_name': '聚2',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.629825353',
#     'longitude': '113.6784231663',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教工宿舍',
#     'name': '聚贤楼3号',
#     'short_name': '聚3',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6294469256',
#     'longitude': '113.6784768105',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教工宿舍',
#     'name': '聚贤楼4号',
#     'short_name': '聚4',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6359390152',
#     'longitude': '113.679946661',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教工宿舍',
#     'name': '聚贤楼5号',
#     'short_name': '聚5',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6362486223',
#     'longitude': '113.6802577972',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教工宿舍',
#     'name': '聚贤楼6号',
#     'short_name': '聚6',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6365336568',
#     'longitude': '113.6806547642',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教工宿舍',
#     'name': '聚贤楼7号',
#     'short_name': '聚7',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6369415499',
#     'longitude': '113.6811053753',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教工宿舍',
#     'name': '聚贤楼8号',
#     'short_name': '聚8',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6353640285',
#     'longitude': '113.6826664209',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教工宿舍',
#     'name': '聚贤楼9号',
#     'short_name': '聚9',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6310146891',
#     'longitude': '113.6812609434',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教工宿舍',
#     'name': '聚贤楼10号',
#     'short_name': '聚10',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6307345572',
#     'longitude': '113.6814326048',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教工宿舍',
#     'name': '聚贤楼11号',
#     'short_name': '聚11',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6311375538',
#     'longitude': '113.6820656061',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '教工宿舍',
#     'name': '员工宿舍',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.6311916142',
#     'longitude': '113.682269454',
#     'contact': {'phone': '', 'address': ''}}],
#   'position': 7,
#   '_id': 'mrWfizMUpejXLXb2mSeShAtiLnoVuxDa17VRpVXKfsQiXNZM'},
#  {'type': '景点',
#   'icon': 'jd',
#   'data': [{'type': '景点',
#     'name': '孙中山铜像',
#     'short_name': '铜像',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 2,
#     'panorama': 2291779,
#     'icon': 'tx@2',
#     'position': 0,
#     'scale': 16.0,
#     '_id': '5ce8fe1c29c7a8581bc1e98b',
#     'latitude': '23.634548',
#     'longitude': '113.676900',
#     'contact': {'phone': '', 'address': '地址'}},
#    {'type': '景点',
#     'name': '校训石',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.634037',
#     'longitude': '113.677393',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '景点',
#     'name': '南芳湖',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 2,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.629113',
#     'longitude': '113.679507',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '景点',
#     'name': '西区公园',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 2,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.629958',
#     'longitude': '113.677726',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '景点',
#     'name': '大礼堂',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 3,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.631772',
#     'longitude': '113.679662',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '景点',
#     'name': '时光隧道',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 0,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.637880',
#     'longitude': '113.675301',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '景点',
#     'name': '壁画墙',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 0,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.628641',
#     'longitude': '113.678332',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '景点',
#     'name': '图书馆',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 11,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.632337',
#     'longitude': '113.679142',
#     'contact': {'phone': '', 'address': ''}}],
#   'scale': 16.0,
#   'position': 0,
#   '_id': '5ce8fe1c29c7a8581bc1e98b'},
#  {'type': '探险',
#   'icon': 'tx',
#   'data': [{'type': '探险',
#     'name': '校长别墅',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 10,
#     'scale': '',
#     '_id': 'wkNEmpv7L4Th8yfd1Dl34gDzSLlnmLFGF16ACmQ7fIZAMzzV',
#     'latitude': '23.635659',
#     'longitude': '113.678386',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '探险',
#     'name': '后山',
#     'short_name': '',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': 'climb',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.632258',
#     'longitude': '113.673241',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '探险',
#     'name': '大礼堂之巅',
#     'short_name': '天台风凉',
#     'desc': '地点描述',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.631629',
#     'longitude': '113.679914',
#     'contact': {'phone': '', 'address': ''}},
#    {'type': '探险',
#     'name': '枫林晚',
#     'short_name': '',
#     'desc': '锦衣夜游好去处',
#     'logo': '',
#     'images': 1,
#     'panorama': 0,
#     'icon': '',
#     'position': 0,
#     'scale': '',
#     '_id': '',
#     'latitude': '23.636455',
#     'longitude': '113.680172',
#     'contact': {'phone': '', 'address': ''}}],
#   'position': 10,
#   '_id': 'wkNEmpv7L4Th8yfd1Dl34gDzSLlnmLFGF16ACmQ7fIZAMzzV'}]

# %% [markdown]
# # Board 处理

# %% [markdown]
# ## 目标数据格式
# ```
# {
#     'type': '信息类型',
#     'data': [
#         {
#             'time': 123456,   # timestamp
#             'content': '信息内容'
#         },
#         ...
#         {...}
#     ]
# }
# ```

# %%
df_board = df_board[df_board.status != 1]
df_board.drop(columns='status', inplace=True)
df_board.head()
# Out:
#    type    time content
# 0  校园动态  123456    测试信息
# 1  校园动态  123456   测试信息2
# 2  讲座论坛  123456   富文本信息

# %%
data_board = [{'type': t, 'data': []} for t in set(df_board.type)] 
for itme in data_board:
    for index, row in df_board.iterrows():
        if row.type == itme['type']:
            itme['data'].append(dict(row))
data_board
# Out:
# [{'type': '校园动态',
#   'data': [{'type': '校园动态', 'time': 123456, 'content': '测试信息'},
#    {'type': '校园动态', 'time': 123456, 'content': '测试信息2'}]},
#  {'type': '讲座论坛',
#   'data': [{'type': '讲座论坛', 'time': 123456, 'content': '富文本信息'}]}]

# %% [markdown]
# ## 输出JSON
# 需要注意以下几点：
#
# 1. JSON 数据不是数组，而是类似 **[JSON Lines](http://jsonlines.org/)**，即各个记录对象之间使用 \n 分隔，而非逗号；
#
# 2. JSON 数据每个键值对的键名首尾不能是 .，例如 ".a"、"abc."，且不能包含多个连续的 .，例如 "a..b"；
#
# 3. 键名不能重复，且不能有歧义，例如 {"a": 1, "a": 2} 或 {"a": {"b": 1}, "a.b": 2}；
#
# 4. 时间格式须为 ISODate 格式，例如 "date": { "$date" : "2018-08-31T17:30:00.882Z" }；
#
# 5. 当使用 Insert 冲突处理模式时，同一文件不能存在重复的 _id 字段，或与数据库已有记录相同的 _id 字段；
#
# 6. CSV 格式的数据默认以第一行作为导入后的所有键名，余下的每一行则是与首行键名一一对应的键值记录。
#
# 参考链接：
# * https://developers.weixin.qq.com/miniprogram/dev/wxcloud/guide/database/import.html?search-key=JSON%20lines

# %%
with jsonlines.open('data.json', mode='w') as writer:
    for i in data:
        writer.write(i)
        
with jsonlines.open('data_board.json', mode='w') as writer:
    for i in data_board:
        writer.write(i)

# %%
with open('data.json', 'w', encoding="utf-8") as f:
    f.write(json.dumps(data, separators='\n', ensure_ascii=False))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-e0b65dadffce> in <module>()
#       1 with open('data.json', 'w', encoding="utf-8") as f:
# ----> 2     f.write(json.dumps(data, separators='\n', ensure_ascii=False))
#
# ~\Anaconda3\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# ~\Anaconda3\lib\json\encoder.py in __init__(self, skipkeys, ensure_ascii, check_circular, allow_nan, sort_keys, indent, separators, default)
#     152         self.indent = indent
#     153         if separators is not None:
# --> 154             self.item_separator, self.key_separator = separators
#     155         elif indent is not None:
#     156             self.item_separator = ','
#
# ValueError: not enough values to unpack (expected 2, got 1)
